# %% [markdown]
# Lê um arquivo .CSV e o transforma em um numpy array
#
# parâmetro pyFDA: table orientation = Vertical

# %%
import pandas as pd
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

dados = pd.read_csv('teste_FIR.csv', header = None)
valores = dados.values
valores = valores[:,0]

print(valores)
fs = 48000
w, h = signal.freqz(valores,[1])


fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot((w/np.pi)*(fs/2), 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [freq]')
ax1.grid()
#ax1.set_ylim([-80, 5])
# Out:
# [-6.06977797e-04 -2.36189829e-03 -3.11492580e-03 -8.80037124e-18
#   7.99614506e-03  1.43009621e-02  6.82762297e-03 -1.86189103e-02
#  -4.48850973e-02 -3.75839953e-02  2.90744749e-02  1.43784527e-01
#   2.54775224e-01  3.00825698e-01  2.54775224e-01  1.43784527e-01
#   2.90744749e-02 -3.75839953e-02 -4.48850973e-02 -1.86189103e-02
#   6.82762297e-03  1.43009621e-02  7.99614506e-03 -8.80037124e-18
#  -3.11492580e-03 -2.36189829e-03 -6.06977797e-04]
